# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/luismontesillo/Downloads/embeddings_fst.csv")
df
X1=df.iloc[:,:100]
X1
# Out:
#        0.05892307  0.038402352  -0.075489864  0.06357275  0.041131273  \
# 0        0.059186     0.039018     -0.073900    0.064061     0.041944
# 1        0.061217     0.039325     -0.075888    0.063163     0.044064
# 2        0.059904     0.038735     -0.075227    0.062948     0.041459
# 3        0.060685     0.038588     -0.075097    0.062135     0.041925
# 4        0.059405     0.039067     -0.074008    0.063049     0.042403
# ...           ...          ...           ...         ...          ...
# 29283    0.082467    -0.094754     -0.021412    0.044419    -0.059212
# 29284    0.072585     0.047321     -0.129371    0.051196     0.009845
# 29285    0.003866     0.042460     -0.099416    0.027585     0.027075
# 29286    0.057304     0.040452     -0.113065    0.034124     0.004688
# 29287    0.057283     0.004232     -0.085143    0.021676    -0.020059
#
#        0.18662365  -0.046560235  0.18860449  0.03903533  -0.1690764  ...  \
# ...

# %%
df = pd.read_csv("/Users/luismontesillo/Downloads/mod_embeddings_w2v.csv")
df
X1=df.iloc[:,:100]
X1
# Out:
#               N0        N1        N2        N3        N4        N5        N6  \
# 0      -0.039106 -0.129636  0.134212 -0.115996  0.094007 -0.124803 -0.090776
# 1      -0.043838 -0.129377  0.134205 -0.109900  0.087036 -0.124986 -0.091542
# 2      -0.042660 -0.128889  0.133422 -0.110226  0.087581 -0.127471 -0.094391
# 3      -0.041107 -0.130399  0.133479 -0.109191  0.086635 -0.123840 -0.095953
# 4      -0.040003 -0.129132  0.134323 -0.103410  0.085192 -0.125791 -0.093571
# ...          ...       ...       ...       ...       ...       ...       ...
# 153084 -0.063032 -0.135601  0.088262 -0.110689  0.140562 -0.006567  0.112575
# 153085 -0.094895  0.095342 -0.080627 -0.026979 -0.104199  0.103075  0.018217
# 153086  0.012665 -0.032021  0.138534  0.130305  0.130073 -0.025985  0.085447
# 153087  0.076149 -0.116132 -0.079565  0.093332  0.133188 -0.113274 -0.133562
# 153088 -0.098389 -0.077510 -0.015675  0.022030  0.125567  0.023823  0.024729
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
x = StandardScaler().fit_transform(X1)

# %%
from sklearn.decomposition import PCA


pca = PCA(n_components=2)

principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf
# Out:
#        principal component 1  principal component 2
# 0                   1.334292              -4.164250
# 1                   1.331159              -4.130108
# 2                   1.441434              -4.214894
# 3                   1.541662              -4.267837
# 4                   1.398919              -4.186852
# ...                      ...                    ...
# 29283              11.354948              -4.950348
# 29284              -2.220179              -2.410189
# 29285              -2.338145              -1.940200
# 29286              -1.806103              -2.709834
# 29287               2.207809              -3.997352
#
# [29288 rows x 2 columns]

# %%
from sklearn.cluster import KMeans

num = 8

clustering = KMeans(n_clusters=num)
clustering.fit(principalDf)
y_clusters = clustering.predict(principalDf)
clusters = clustering.labels_

# %%
plt.figure()
plt.scatter(principalDf["principal component 1"],principalDf["principal component 2"],c=y_clusters)
plt.show()

# %%
emotion = df.iloc[:,100:101]
emotion=np.unique(emotion)
emotion

# em_dict={}
# emotion=np.unique(emotion)
# for element in enumerate(emotion):
#     print(element)
#     em_dict[element[1]]=element[0]
# em_dict
# x2=np.append(x,df.iloc[:,100:101],axis=1)
# x2[:,:,]
# x.shape
# Out:
# array(['anger', 'anticipation', 'disgust', 'fear', 'joy', 'sadness',
#        'surprise', 'trust'], dtype=object)

# %%
principalDf.insert(2, "emotion", df.iloc[:,100:101], True)

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
fig,ax = plt.subplots()

labels=emotion
for element in enumerate(emotion):
    data = principalDf[principalDf["emotion"]== element[1]]
    ax.scatter(data["principal component 1"],data["principal component 2"],label=emotion,s=10,alpha=0.5)

ax.legend(emotion)
fig.set_dpi(500)
ax.title.set_text("mod_fst")

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
fig,ax = plt.subplots()

labels=emotion
for element in enumerate(emotion):
    data = principalDf[principalDf["emotion"]== element[1]]
    ax.scatter(data["principal component 1"],data["principal component 2"],label=emotion,s=10,alpha=0.5)

ax.legend(emotion)
fig.set_dpi(500)
ax.title.set_text("mod_fst")
# principalDf[principalDf["emotion"]== "anger"].plot.scatter(x='principal component 1', y='principal component 2')
# principalDf[principalDf["emotion"]== "anticipation"].plot.scatter(x='principal component 1', y='principal component 2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from matplotlib.pyplot import figure
#       3 fig,ax = plt.subplots()
# ----> 5 labels=emotion
#       6 for element in enumerate(emotion):
#       7     data = principalDf[principalDf["emotion"]== element[1]]
#
# NameError: name 'emotion' is not defined

# %%
from sklearn.cluster import KMeans

num = 5

clustering = KMeans(n_clusters=num)
clustering.fit(principalDf)
y_clusters = clustering.predict(principalDf)
clusters = clustering.labels_

plt.figure()
plt.scatter(principalDf.iloc[:,0],principalDf.iloc[:,1],c=y_clusters,alpha=0.5)
plt.gcf().set_dpi(500)
plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

X=X1
kmeans_labels=y_clusters
for i in range(8):

    num=i+2

    clustering = KMeans(n_clusters=num)
    clustering.fit(principalDf)
    y_clusters = clustering.predict(principalDf)
    clusters = clustering.labels_

    kmeans_labels=y_clusters
    print(f"numero de clusters:{num}")
    # Silhouette Score
    silhouette_avg = silhouette_score(X, kmeans_labels)
    print(f"Silhouette Score: {silhouette_avg}")

    # Davies-Bouldin Index
    davies_bouldin = davies_bouldin_score(X, kmeans_labels)
    print(f"Davies-Bouldin Index: {davies_bouldin}")

    # Calinski-Harabasz Index
    calinski_harabasz = calinski_harabasz_score(X, kmeans_labels)
    print(f"Calinski-Harabasz Index: {calinski_harabasz}")
# Out:
# numero de clusters:2
# Silhouette Score: 0.04504239899333775
# Davies-Bouldin Index: 2.916424277084774
# Calinski-Harabasz Index: 7708.646203137343
# numero de clusters:3
# Silhouette Score: 0.05799010148700217
# Davies-Bouldin Index: 2.6928031920600204
# Calinski-Harabasz Index: 7643.1560094356055
# numero de clusters:4
# Silhouette Score: 0.06681391939766052
# Davies-Bouldin Index: 2.602380550490785
# Calinski-Harabasz Index: 7483.336179556571
# numero de clusters:5
# Silhouette Score: 0.07166992951249708
# Davies-Bouldin Index: 3.912480419431713
# Calinski-Harabasz Index: 6602.848854273393
# numero de clusters:6
# Silhouette Score: 0.06877343644985408
# Davies-Bouldin Index: 4.867664142134526
# Calinski-Harabasz Index: 5615.508311840676
# numero de clusters:7
# Silhouette Score: 0.06642320476536867
# Davies-Bouldin Index: 5.034659436577054
# Calinski-Harabasz Index: 5052.609874349217
# numero de clusters:8
# Silhouette Score: 0.0655206604635914
# ...
